# %% [markdown]
# **Name:-Ankit Gaidhar**

# %% [markdown]
# **RollNo:-D2_28**

# %% [markdown]
# **Subject:- ML
# PRACTICAL 01**

# %%
import pandas as pd

# %%
df1=pd.read_csv("bank.csv")

# %%
df1.describe()
# Out:
#                 age       balance           day      duration      campaign  \
# count  11162.000000  11162.000000  11162.000000  11162.000000  11162.000000
# mean      41.231948   1528.538524     15.658036    371.993818      2.508421
# std       11.913369   3225.413326      8.420740    347.128386      2.722077
# min       18.000000  -6847.000000      1.000000      2.000000      1.000000
# 25%       32.000000    122.000000      8.000000    138.000000      1.000000
# 50%       39.000000    550.000000     15.000000    255.000000      2.000000
# 75%       49.000000   1708.000000     22.000000    496.000000      3.000000
# max       95.000000  81204.000000     31.000000   3881.000000     63.000000
#
#               pdays      previous
# count  11162.000000  11162.000000
# mean      51.330407      0.832557
# std      108.758282      2.292007
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       20.750000      1.000000
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   default    11162 non-null  object
#  5   balance    11162 non-null  int64
#  6   housing    11162 non-null  object
#  7   loan       11162 non-null  object
#  8   contact    11162 non-null  object
#  9   day        11162 non-null  int64
#  10  month      11162 non-null  object
#  11  duration   11162 non-null  int64
#  12  campaign   11162 non-null  int64
#  13  pdays      11162 non-null  int64
#  14  previous   11162 non-null  int64
#  15  poutcome   11162 non-null  object
#  16  deposit    11162 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
df1.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df1.tail()
# Out:
#        age          job  marital  education default  balance housing loan  \
# 11157   33  blue-collar   single    primary      no        1     yes   no
# 11158   39     services  married  secondary      no      733      no   no
# 11159   32   technician   single  secondary      no       29      no   no
# 11160   43   technician  married  secondary      no        0      no  yes
# 11161   34   technician  married  secondary      no        0      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 11157  cellular   20   apr       257         1     -1         0  unknown
# 11158   unknown   16   jun        83         4     -1         0  unknown
# 11159  cellular   19   aug       156         2     -1         0  unknown
# 11160  cellular    8   may         9         2    172         5  failure
# 11161  cellular    9   jul       628         1     -1         0  unknown
#
#       deposit
# 11157      no
# 11158      no
# 11159      no
# 11160      no
# ...

# %%
df1.shape
# Out:
# (11162, 17)

# %%
#Check null or missing values
df1.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
#handing null or  missing values
df1.fillna(df1.mean(), inplace=True)
#Dropping missing values
df1.dropna(inplace=True)
# Out:
# <ipython-input-17-718c6c714723>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   dataset1.fillna(dataset1.mean(), inplace=True)

# %%
#check for duplicates
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, deposit]
# Index: []

# %%
#remove duplicates

# %%
df1.drop_duplicates(inplace=True)

# %%
df1[df1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, deposit]
# Index: []

# %%
#Outliers using scatter plot
import seaborn as sns
import matplotlib.pyplot as plt

fig,p=plt.subplots(figsize=(12,7))
p.scatter(df1['age'],df1['balance'])
p.set_xlabel('Age')

p.set_ylabel('Balance')
plt.show()

# %%
# Position of the Outliers(balance>20000 or age>60) according to the graph
outliers=np.where((df1['balance']>20000) | (df1['age']>60))
print(outliers)
# Out:
# (array([  682,   771,   813,  1010,  1073,  1130,  1142,  1162,  1168,
#         1180,  1199,  1214,  1224,  1229,  1236,  1237,  1243,  1245,
#         1247,  1258,  1259,  1262,  1264,  1267,  1271,  1274,  1281,
#         1282,  1291,  1312,  1320,  1335,  1337,  1343,  1371,  1373,
#         1380,  1388,  1395,  1426,  1445,  1468,  1469,  1472,  1473,
#         1477,  1479,  1484,  1487,  1537,  1551,  1552,  1558,  1561,
#         1567,  1581,  1582,  1583,  1586,  1591,  1602,  1603,  1604,
#         1613,  1616,  1623,  1629,  1632,  1633,  1731,  1737,  1744,
#         1780,  2132,  2226,  2258,  2323,  2340,  2341,  2342,  2344,
#         2345,  2351,  2352,  2356,  2379,  2382,  2383,  2388,  2397,
#         2398,  2408,  2421,  2436,  2440,  2441,  2442,  2443,  2448,
#         2450,  2452,  2461,  2468,  2473,  2492,  2495,  2506,  2516,
#         2531,  2534,  2543,  2544,  2548,  2557,  2578,  2583,  2591,
# ...

# %%
#Removing the outliers
for i in outliers:
  df1=df1.drop(i)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10506 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        10506 non-null  int64
#  1   job        10506 non-null  object
#  2   marital    10506 non-null  object
#  3   education  10506 non-null  object
#  4   default    10506 non-null  object
#  5   balance    10506 non-null  int64
#  6   housing    10506 non-null  object
#  7   loan       10506 non-null  object
#  8   contact    10506 non-null  object
#  9   day        10506 non-null  int64
#  10  month      10506 non-null  object
#  11  duration   10506 non-null  int64
#  12  campaign   10506 non-null  int64
#  13  pdays      10506 non-null  int64
#  14  previous   10506 non-null  int64
#  15  poutcome   10506 non-null  object
#  16  deposit    10506 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 1.4+ MB

# %%
df1.shape
# Out:
# (10506, 17)

# %%
fig,p=plt.subplots(figsize=(6,5))
p.scatter(df1['age'],df1['balance'])
p.set_xlabel('Age')

p.set_ylabel('Balance')
plt.show()  #we can see outliers are reduced.

# %%
#identifying the outliers and handling it Using Z_Score

from scipy import stats
import numpy as np

z=np.abs(stats.zscore(df1['age']))
print(z)
# Out:
# 0        1.491505
# 1        1.239676
# 2        0.019470
# 3        1.155733
# 4        1.071790
#            ...
# 11157    0.691015
# 11158    0.187357
# 11159    0.774958
# 11160    0.148416
# 11161    0.607072
# Name: age, Length: 11162, dtype: float64

# %%
#to get the outliers z>2
#threshold=2
print(np.where(z>2))
# Out:
# (array([ 1142,  1162,  1168,  1180,  1199,  1214,  1229,  1236,  1237,
#         1243,  1245,  1247,  1258,  1262,  1267,  1274,  1281,  1291,
#         1320,  1337,  1371,  1373,  1380,  1388,  1426,  1445,  1472,
#         1479,  1487,  1537,  1552,  1558,  1561,  1567,  1582,  1586,
#         1591,  1603,  1613,  1616,  1623,  1629,  1633,  1731,  2340,
#         2344,  2345,  2351,  2352,  2356,  2382,  2388,  2397,  2398,
#         2408,  2421,  2441,  2442,  2443,  2448,  2450,  2452,  2461,
#         2473,  2492,  2506,  2516,  2543,  2544,  2557,  2583,  2592,
#         2596,  2598,  2599,  2605,  2629,  2641,  2653,  2664,  2665,
#         2666,  2670,  2681,  2683,  2686,  2687,  2689,  2708,  2709,
#         2713,  2717,  2722,  2746,  2747,  2754,  2756,  2764,  2765,
#         2770,  2778,  2781,  2782,  2793,  2797,  2802,  2804,  2808,
#         2809,  2811,  2820,  2823,  2824,  2825,  2837,  2839,  2850,
# ...

# %%
#Data Encoding
from sklearn.preprocessing import LabelEncoder #LabelEncoder assigns Unique integer values.

# Identify categorical columns
categorical_cols = df1.select_dtypes(include=['object']).columns.tolist()

# Apply label encoding
label_encoder = LabelEncoder()
for col in categorical_cols:
    df1[col] = label_encoder.fit_transform(df1[col])

# %%
df1.info() #we can see all columns datatype are now same int64
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10506 entries, 0 to 11161
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        10506 non-null  int64
#  1   job        10506 non-null  int64
#  2   marital    10506 non-null  int64
#  3   education  10506 non-null  int64
#  4   default    10506 non-null  int64
#  5   balance    10506 non-null  int64
#  6   housing    10506 non-null  int64
#  7   loan       10506 non-null  int64
#  8   contact    10506 non-null  int64
#  9   day        10506 non-null  int64
#  10  month      10506 non-null  int64
#  11  duration   10506 non-null  int64
#  12  campaign   10506 non-null  int64
#  13  pdays      10506 non-null  int64
#  14  previous   10506 non-null  int64
#  15  poutcome   10506 non-null  int64
#  16  deposit    10506 non-null  int64
# dtypes: int64(17)
# memory usage: 1.4 MB

# %%
df1.head(10)
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   59    0        1          1        0     2343        1     0        2
# 1   56    0        1          1        0       45        0     0        2
# 2   41    9        1          1        0     1270        1     0        2
# 3   55    7        1          1        0     2476        1     0        2
# 4   54    0        1          2        0      184        0     0        2
# 5   42    4        2          2        0        0        1     1        2
# 6   56    4        1          2        0      830        1     1        2
# 7   60    5        0          1        0      545        1     0        2
# 8   37    9        1          1        0        1        1     0        2
# 9   28    7        2          1        0     5090        1     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  deposit
# 0    5      8      1042         1     -1         0         3        1
# ...

# %%
df1.tail(20)
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 11142   52    0        0          1        0       48        0     1        0
# 11143   38   10        0          1        0      189        1     1        0
# 11144   60    5        1          1        0        0        1     0        2
# 11145   60    5        0          2        0     -134        0     0        0
# 11146   30    0        1          1        1       23        0     1        0
# 11147   44   10        1          1        0        0        0     0        0
# 11148   32    1        1          1        0        1        1     0        2
# 11149   46    2        1          1        0     3317        0     0        0
# 11150   34    4        1          1        0      355        0     0        0
# 11151   40    4        1          2        0      917        1     0        2
# 11152   34    3        1          1        0      390        1     0        0
# ...

# %%
#Univariate, Bivariate & Multivariate analysis

sns.histplot(df1['balance'], kde=True)
plt.title('Histogram of Balance')
plt.show()#Univariate

# %%
#Bivariate
sns.scatterplot(x='age', y='duration', data=df1)
plt.title('Scatter Plot between age and Numerical duration')
plt.show()
